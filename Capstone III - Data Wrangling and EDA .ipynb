# %%
#pip install wordcloud

# %%
#Import pandas, matplotlib.pyplot, and wordcloud
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('Chatbot_QA_DraftB.csv', sep=',', engine='python')
df
# Out:
#                        Topic  \
# 0      General Data Science
# 1      General Data Science
# 2      General Data Science
# 3      General Data Science
# 4      General Data Science
# ..                       ...
# 163  SQL and Database Design
# 164  SQL and Database Design
# 165  SQL and Database Design
# 166  SQL and Database Design
# 167  SQL and Database Design
#
#                                              Questions  \
# 0    What’s the difference between supervised and u...
# 1                         What Is logistic regression?
# 2                             What Is a decision tree?
# 3                       What is decision tree pruning?
# 4                                     What is entropy?
# ..                                                 ...
# 163            When do you use the CASE WHEN function?
# 164  What's the difference between a LEFT JOIN and ...
# 165            When would you use UNION vs UNION ALL?
# ...

# %%
#Word Cloud of Questions
words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file

for val in df.Questions:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    words += " ".join(tokens) + " "
 
wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='black',
                    stopwords = stopwords,
                    min_font_size = 10).generate(words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
#Word Cloud of Answers
words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file

for val in df.Answers:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    words += " ".join(tokens) + " "
 
wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='black',
                    stopwords = stopwords,
                    min_font_size = 10).generate(words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
#Create word cloud of questions by topics
df['Topic'].unique()
# Out:
# array(['General Data Science ', 'Data Structures and Algorithms',
#        'SQL and Database Design'], dtype=object)

# %%
#Word Clouds of Questions by the 3 Main Topics
words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for topic in list(df['Topic'].unique()):
    for val in df[df['Topic'] == topic].Questions:

        # typecaste each val to string
        val = str(val)

        # split the value
        tokens = val.split()

        # Converts each token into lowercase
        for i in range(len(tokens)):
            tokens[i] = tokens[i].lower()

        words += " ".join(tokens) + " "

    wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='black',
                    stopwords = stopwords,
                    min_font_size = 10).generate(words)

    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()

# %%
#Word Clouds of Answers by the 3 Main Topics
words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for topic in list(df['Topic'].unique()):
    for val in df[df['Topic'] == topic].Answers:

        # typecaste each val to string
        val = str(val)

        # split the value
        tokens = val.split()

        # Converts each token into lowercase
        for i in range(len(tokens)):
            tokens[i] = tokens[i].lower()

        words += " ".join(tokens) + " "

    wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='black',
                    stopwords = stopwords,
                    min_font_size = 10).generate(words)

    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()
